# %% [markdown]
# # SWIGGY SALES ANALYSIS

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
# !pip install plotly.express
# Out:
# Requirement already satisfied: plotly.express in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (0.4.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly.express) (6.6.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly.express) (0.14.6)
# Requirement already satisfied: scipy>=0.18 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly.express) (1.17.1)
# Requirement already satisfied: patsy>=0.5 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly.express) (1.0.2)
# Requirement already satisfied: numpy>=1.11 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly.express) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly>=4.1.0->plotly.express) (2.18.0)
# Requirement already satisfied: packaging in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\prateek\appdata\local\programs\python\python314\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl as pyxl
import plotly.express as px

# %% [markdown]
# ### IMPORT DATA

# %%
df=pd.read_excel(r"C:\Users\prateek\Downloads\swiggy_data.xlsx")

# %%
df.head(10)
# Out:
#        State       City Order Date           Restaurant Name  \
# 0  Karnataka  Bengaluru 2025-06-29  Anand Sweets & Savouries
# 1  Karnataka  Bengaluru 2025-04-03     Srinidhi Sagar Deluxe
# 2  Karnataka  Bengaluru 2025-01-15     Srinidhi Sagar Deluxe
# 3  Karnataka  Bengaluru 2025-04-17     Srinidhi Sagar Deluxe
# 4  Karnataka  Bengaluru 2025-03-13     Srinidhi Sagar Deluxe
# 5  Karnataka  Bengaluru 2025-07-08     Srinidhi Sagar Deluxe
# 6  Karnataka  Bengaluru 2025-01-21     Srinidhi Sagar Deluxe
# 7  Karnataka  Bengaluru 2025-04-13     Srinidhi Sagar Deluxe
# 8  Karnataka  Bengaluru 2025-05-02     Srinidhi Sagar Deluxe
# 9  Karnataka  Bengaluru 2025-07-30     Srinidhi Sagar Deluxe
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   State            197430 non-null  object
#  1   City             197430 non-null  object
#  2   Order Date       197430 non-null  datetime64[ns]
#  3   Restaurant Name  197430 non-null  object
#  4   Location         197430 non-null  object
#  5   Category         197430 non-null  object
#  6   Dish Name        197430 non-null  object
#  7   Price (INR)      197430 non-null  float64
#  8   Rating           197430 non-null  float64
#  9   Rating Count     197430 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 15.1+ MB

# %%
print("no. of rows:", df.shape[0])
print("no. of colums:", df.shape[1])
# Out:
# no. of rows: 197430
# no. of colums: 10

# %% [markdown]
# ### DATA TYPES

# %%
df.isnull().sum()
# Out:
# State              0
# City               0
# Order Date         0
# Restaurant Name    0
# Location           0
# Category           0
# Dish Name          0
# Price (INR)        0
# Rating             0
# Rating Count       0
# dtype: int64

# %%
df.describe()
# Out:
#                           Order Date    Price (INR)         Rating  \
# count                         197430  197430.000000  197430.000000
# mean   2025-05-01 19:41:20.996808960     268.512920       4.341582
# min              2025-01-01 00:00:00       0.950000       1.500000
# 25%              2025-03-01 00:00:00     139.000000       4.300000
# 50%              2025-05-02 00:00:00     229.000000       4.400000
# 75%              2025-07-01 00:00:00     329.000000       4.500000
# max              2025-08-31 00:00:00    8000.000000       5.000000
# std                              NaN     219.338363       0.422585
#
#         Rating Count
# count  197430.000000
# mean       28.321805
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%        15.000000
# max       999.000000
# std        87.542593

# %%
df.dtypes
# Out:
# State                      object
# City                       object
# Order Date         datetime64[ns]
# Restaurant Name            object
# Location                   object
# Category                   object
# Dish Name                  object
# Price (INR)               float64
# Rating                    float64
# Rating Count                int64
# dtype: object

# %% [markdown]
# # KPI's

# %%
df.columns
# Out:
# Index(['State', 'City', 'Order Date', 'Restaurant Name', 'Location',
#        'Category', 'Dish Name', 'Price (INR)', 'Rating', 'Rating Count'],
#       dtype='object')

# %% [markdown]
# ### TOTAL SALES

# %%
total_sales = df[ 'Price (INR)'].sum()
print("Total sales (INR):",round(total_sales,2))
# Out:
# Total sales (INR): 53012505.77

# %% [markdown]
# ### AVERAGE RATING

# %%
avg = df['Rating'].mean()
print("TOTAL AVERAGE RATING:",round(avg,2))
# Out:
# TOTAL AVERAGE RATING: 4.34

# %% [markdown]
# ### AVERAGE ORDER

# %%
avg_order_val = df[ 'Price (INR)'].mean()
print("avg order value:",round(avg_order_val,2))
# Out:
# avg order value: 268.51

# %% [markdown]
# ### TOTAL RATING COUNTS

# %%
total_Rating_Counts = df[ 'Rating Count'].sum()
print("Total sales (INR):",total_Rating_Counts)
# Out:
# Total sales (INR): 5591574

# %% [markdown]
# ### TOTAL ORDERS

# %%
total_orders = df['Order Date'].count()
print("Total_orders:",total_orders)
# Out:
# Total_orders: 197430

# %% [markdown]
# ## VISUALIZATION

# %% [markdown]
# ### MONTHLY SALES TREND

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df["YearMonth"] = df['Order Date'].dt.to_period("M").astype(str)

monthly_revenue = df.groupby("YearMonth")['Price (INR)'].sum().reset_index()

plt.figure()
plt.plot(monthly_revenue["YearMonth"],monthly_revenue['Price (INR)'])
plt.title("MONTHLY SALES TREND")
plt.xlabel("Months")
plt.ylabel("Revenue (INR)")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### DAILY SALES TREND

# %%
df['Dayname'] = pd.to_datetime(df['Order Date']).dt.day_name()

Daily_revenue = (
     df.groupby("Dayname")['Price (INR)']
    .sum()
    .reindex(["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"])
)

plt.figure(figsize=(10,5))
plt.bar(Daily_revenue.index, Daily_revenue.values)
plt.title("DAILY SALES TREND")
plt.xlabel("Daily")
plt.ylabel("Revenue (INR)")
plt.xticks(rotation = 45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### TOTAL SALES BY FOOD TYPE (NON-VEG OR VEG)

# %%
non_veg_keywords = [
                    "chicken", "fish", "egg", "mutton",
                    "prawns", "biryani", "kebab", "kabab",
                    "non-veg", "non veg"
                   ]

df["Food Category"] = np.where(
    df["Dish Name"].str.lower().str.contains("|".join(non_veg_keywords ), na=False),
    "Non-Veg",
    "Veg"
)

# %%
food_revenue = (
    df.groupby("Food Category")["Price (INR)"]
    .sum()
    .reset_index()
)

# %%
fig = px.pie(
    food_revenue,
    values = "Price (INR)",
    names = "Food Category",
    hole = 0.5,
    title = "TOTAL SALES BY FOOD TYPE (NON-VEG OR VEG)"
)

fig.update_traces(
    textinfo = "percent + label",
    pull = [0.05, 0]
)

fig.update_layout(
    height = 500,
    margin= dict(t=60, b=40, l=40, r=40)
)

fig.show()

# %% [markdown]
# ### TOTAL SALES BY STATES

# %%
fig = px.bar(
    df.groupby('State',as_index=False)['Price (INR)'].sum()
    .sort_values('Price (INR)', ascending=False),
    x = 'Price (INR)',
    y = 'State',
    orientation = 'h',
    title = "REVENUE SALES BY SATES"
)

fig.update_layout(height=600, yaxis=dict(autorange='reversed'))
fig.show()

# %% [markdown]
# ### QUATERLY PERFORMANCE SUMMARY

# %%
df["Order_Date"] = pd.to_datetime(df["Order Date"])
df["Quarter"] = df["Order_Date"].dt.to_period("Q").astype(str)
quarterly_summary = (
    df.groupby("Quarter", as_index = False)
    .agg(
        total_sales=("Price (INR)","sum"),
        avg_ratings=("Rating", "mean"),
        total_orders=("Order_Date", "count")
    )
    .sort_values("Quarter")
)

# %% [markdown]
# ### TOP 5 CITIES BY SALES

# %%
top_5_cities =(df.groupby("City")["Price (INR)"].sum().nlargest(5).sort_values().reset_index())

fig = px.bar(
    top_5_cities,
    x= "Price (INR)",
    y="City",
    orientation = 'h',
    title = "Top 5 cities by sales (INR)",
    color_discrete_sequence=["red"]
)

fig.show()
